# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("country_vaccination_stats.csv")
df
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 NaN
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
df.isnull().sum()
# Out:
# country                0
# date                   0
# daily_vaccinations    60
# vaccines               0
# dtype: int64

# %%
data["daily_vaccinations"].value_counts()
# Out:
# 3000.0      22
# 63.0        21
# 187500.0    16
# 62.0        12
# 13200.0     10
#             ..
# 19721.0      1
# 87584.0      1
# 86392.0      1
# 85096.0      1
# 17063.0      1
# Name: daily_vaccinations, Length: 1224, dtype: int64

# %%
missing_data = df[df['daily_vaccinations'].isnull()]

# missing_value print
print("Eksik Veriler:")
print(missing_data)
# Out:
# Eksik Veriler:
#                    country        date  daily_vaccinations  \
# 0                Argentina  12/29/2020                 NaN
# 28                 Austria    1/5/2021                 NaN
# 48                 Bahrain  12/23/2020                 NaN
# 77                 Belgium  12/28/2020                 NaN
# 103                 Brazil   1/16/2021                 NaN
# 113               Bulgaria  12/29/2020                 NaN
# 141                 Canada  12/14/2020                 NaN
# 184                  Chile  12/24/2020                 NaN
# 217                  China  12/15/2020                 NaN
# 254             Costa Rica  12/24/2020                 NaN
# 280                Croatia  12/30/2020                 NaN
# 307                 Cyprus    1/6/2021                 NaN
# 324                Czechia  12/27/2020                 NaN
# 354                Denmark  12/27/2020                 NaN
# 384                Ecuador   1/21/2021                 NaN
# ...

# %%
# Group by country and calculate the minimum daily vaccination number for each country
min_vaccinations = df.groupby("country")["daily_vaccinations"].min().reset_index()

# Merge the original dataframe with the minimum daily vaccination numbers
df = pd.merge(df, min_vaccinations, on="country", suffixes=("", "_min"))

# Fill missing values in daily_vaccinations column with the minimum daily vaccination number
df["daily_vaccinations"].fillna(df["daily_vaccinations_min"], inplace=True)

# Fill remaining missing values with 0
df["daily_vaccinations"].fillna(0, inplace=True)

# %%
df
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020              6483.0
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines  daily_vaccinations_min
# 0                               Sputnik V                  6483.0
# 1                               Sputnik V                  6483.0
# 2                               Sputnik V                  6483.0
# 3                               Sputnik V                  6483.0
# ...

# %%
# Drop the minimum daily vaccination number column
df.drop(["daily_vaccinations_min"], inplace=True,axis=1)

# %%
df
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020              6483.0
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
df.isnull().sum()
# Out:
# country               0
# date                  0
# daily_vaccinations    0
# vaccines              0
# dtype: int64

# %%
data["daily_vaccinations"].value_counts()
# Out:
# 3000.0      22
# 63.0        21
# 187500.0    16
# 62.0        12
# 13200.0     10
#             ..
# 19721.0      1
# 87584.0      1
# 86392.0      1
# 85096.0      1
# 17063.0      1
# Name: daily_vaccinations, Length: 1224, dtype: int64

# %%
# Save the updated dataframe to a new CSV file
df.to_csv("output.csv", index=False)
